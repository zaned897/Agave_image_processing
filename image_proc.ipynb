# %%
"""
        Análisis multi-espectral en plantas de Arándano.
Código expreimental para el alineamiento de las imágenes crudas. 

Cámara: Micasense Red Edge.
Altura: < 10m.

@autor: Eduardo Santos, Alberto de Obeso, Raúl Venegas, César Salgado.
fecha: Octubre 2020.
"""

# %% [markdown]
# # Images load

# %%
# Carga de librerias externas
import cv2
import numpy as np
import glob
import matplotlib.pyplot as plt
import imagepross

# %%
# Read all images in the folder
# Masked channels are: 0->red | 1->green | 2->blue | 3->nir | 4-> red edge
Masked = imagepross.read_image_folder('./data/SET002')
rgb = Masked[:,:,0:3] # RGB is equal to merge the first 3 channels
plt.imshow(Masked[:,:,0:3])

# %% [markdown]
# # Images alignament

# %%
import imagepross
# Aling the 5 channels 
X = imagepross.align_all_images(Masked=Masked)

plt.figure(figsize=(15,13))
plt.subplot(121),plt.imshow(Masked[:,:,0:3])
plt.subplot(122),plt.imshow(X[:,:,0:3]), plt.show()
# Out:
# (<AxesSubplot:>, <matplotlib.image.AxesImage at 0x7f11c02f29d0>, None)
